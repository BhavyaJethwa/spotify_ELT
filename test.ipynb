# %%
x = {
    "artists": {
      "href": "https://api.spotify.com/v1/search?query=Amit+Trivedi&type=artist&offset=0&limit=20",
      "items": [
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7HCqGPJcQTyGJ2yqntbuyr"
          },
          "followers": {
            "href": null,
            "total": 8611348
          },
          "genres": [
            "filmi",
            "modern bollywood"
          ],
          "href": "https://api.spotify.com/v1/artists/7HCqGPJcQTyGJ2yqntbuyr",
          "id": "7HCqGPJcQTyGJ2yqntbuyr",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab6761610000e5eb1dcbb331f2318db2dd2c6bcf",
              "width": 640
            },
            {
              "height": 320,
              "url": "https://i.scdn.co/image/ab676161000051741dcbb331f2318db2dd2c6bcf",
              "width": 320
            },
            {
              "height": 160,
              "url": "https://i.scdn.co/image/ab6761610000f1781dcbb331f2318db2dd2c6bcf",
              "width": 160
            }
          ],
          "name": "Amit Trivedi",
          "popularity": 68,
          "type": "artist",
          "uri": "spotify:artist:7HCqGPJcQTyGJ2yqntbuyr"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/3TttERM9n1ASk6Afa8Vgjt"
          },
          "followers": {
            "href": null,
            "total": 14495
          },
          "genres": [],
          "href": "https://api.spotify.com/v1/artists/3TttERM9n1ASk6Afa8Vgjt",
          "id": "3TttERM9n1ASk6Afa8Vgjt",
          "images": [],
          "name": "Amit Trivedi, Shashaa Tirupati, Yazin Nizar",
          "popularity": 40,
          "type": "artist",
          "uri": "spotify:artist:3TttERM9n1ASk6Afa8Vgjt"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/2fMqTqiTxUDlmcOEPaQSsx"
          },
          "followers": {
            "href": null,
            "total": 638421
          },
          "genres": [
            "modern bollywood"
          ],
          "href": "https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx",
          "id": "2fMqTqiTxUDlmcOEPaQSsx",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab6761610000e5eb9ead3cc9a2db015a9871ecdd",
              "width": 640
            },
            {
              "height": 320,
              "url": "https://i.scdn.co/image/ab676161000051749ead3cc9a2db015a9871ecdd",
              "width": 320
            },
            {
              "height": 160,
              "url": "https://i.scdn.co/image/ab6761610000f1789ead3cc9a2db015a9871ecdd",
              "width": 160
            }
          ],
          "name": "Amitabh Bhattacharya",
          "popularity": 78,
          "type": "artist",
          "uri": "spotify:artist:2fMqTqiTxUDlmcOEPaQSsx"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/3l5NND98Neru33dXEYX7ie"
          },
          "followers": {
            "href": null,
            "total": 2889
          },
          "genres": [],
          "href": "https://api.spotify.com/v1/artists/3l5NND98Neru33dXEYX7ie",
          "id": "3l5NND98Neru33dXEYX7ie",
          "images": [],
          "name": "Shreya Ghoshal, Amit Trivedi, Anurag Kulkarni",
          "popularity": 25,
          "type": "artist",
          "uri": "spotify:artist:3l5NND98Neru33dXEYX7ie"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O"
          },
          "followers": {
            "href": null,
            "total": 27414316
          },
          "genres": [
            "desi hip hop",
            "filmi",
            "tamil hip hop"
          ],
          "href": "https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O",
          "id": "4zCH9qm4R2DADamUHMCa6O",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab6761610000e5ebfc7c542c04b5f7dc8f1b1c16",
              "width": 640
            },
            {
              "height": 320,
              "url": "https://i.scdn.co/image/ab67616100005174fc7c542c04b5f7dc8f1b1c16",
              "width": 320
            },
            {
              "height": 160,
              "url": "https://i.scdn.co/image/ab6761610000f178fc7c542c04b5f7dc8f1b1c16",
              "width": 160
            }
          ],
          "name": "Anirudh Ravichander",
          "popularity": 82,
          "type": "artist",
          "uri": "spotify:artist:4zCH9qm4R2DADamUHMCa6O"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/4RAVctZo368nx7X8vGQYts"
          },
          "followers": {
            "href": null,
            "total": 1
          },
          "genres": [],
          "href": "https://api.spotify.com/v1/artists/4RAVctZo368nx7X8vGQYts",
          "id": "4RAVctZo368nx7X8vGQYts",
          "images": [],
          "name": "Amit Trivedi, Shalmali Kholgade, Kausar Munir",
          "popularity": 0,
          "type": "artist",
          "uri": "spotify:artist:4RAVctZo368nx7X8vGQYts"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/6kNKUYGn6VNGsRoXmyoDPK"
          },
          "followers": {
            "href": null,
            "total": 702769
          },
          "genres": [
            "australian metalcore",
            "melodic metalcore",
            "metalcore"
          ],
          "href": "https://api.spotify.com/v1/artists/6kNKUYGn6VNGsRoXmyoDPK",
          "id": "6kNKUYGn6VNGsRoXmyoDPK",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab6761610000e5eba824c84700ff4aae26c8068c",
              "width": 640
            },
            {
              "height": 320,
              "url": "https://i.scdn.co/image/ab67616100005174a824c84700ff4aae26c8068c",
              "width": 320
            },
            {
              "height": 160,
              "url": "https://i.scdn.co/image/ab6761610000f178a824c84700ff4aae26c8068c",
              "width": 160
            }
          ],
          "name": "The Amity Affliction",
          "popularity": 59,
          "type": "artist",
          "uri": "spotify:artist:6kNKUYGn6VNGsRoXmyoDPK"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/1SSLxaY24HiCbAJxOijTnB"
          },
          "followers": {
            "href": null,
            "total": 0
          },
          "genres": [],
          "href": "https://api.spotify.com/v1/artists/1SSLxaY24HiCbAJxOijTnB",
          "id": "1SSLxaY24HiCbAJxOijTnB",
          "images": [],
          "name": "Bhoomi Trivedi, Siddharth Amit Bhavsar",
          "popularity": 2,
          "type": "artist",
          "uri": "spotify:artist:1SSLxaY24HiCbAJxOijTnB"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/2LgKrgRJcbJlt14i1LTzDU"
          },
          "followers": {
            "href": null,
            "total": 887977
          },
          "genres": [
            "filmi",
            "modern bollywood"
          ],
          "href": "https://api.spotify.com/v1/artists/2LgKrgRJcbJlt14i1LTzDU",
          "id": "2LgKrgRJcbJlt14i1LTzDU",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab6761610000e5ebf1d5222e64aed9da230fd501",
              "width": 640
            },
            {
              "height": 320,
              "url": "https://i.scdn.co/image/ab67616100005174f1d5222e64aed9da230fd501",
              "width": 320
            },
            {
              "height": 160,
              "url": "https://i.scdn.co/image/ab6761610000f178f1d5222e64aed9da230fd501",
              "width": 160
            }
          ],
          "name": "Amit Mishra",
          "popularity": 57,
          "type": "artist",
          "uri": "spotify:artist:2LgKrgRJcbJlt14i1LTzDU"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/7otKEEPmJw1z4m8DzxGrQR"
          },
          "followers": {
            "href": null,
            "total": 14
          },
          "genres": [],
          "href": "https://api.spotify.com/v1/artists/7otKEEPmJw1z4m8DzxGrQR",
          "id": "7otKEEPmJw1z4m8DzxGrQR",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab67616d0000b273cba3ae11b1c97fa023c086e0",
              "width": 640
            },
            {
              "height": 300,
              "url": "https://i.scdn.co/image/ab67616d00001e02cba3ae11b1c97fa023c086e0",
              "width": 300
            },
            {
              "height": 64,
              "url": "https://i.scdn.co/image/ab67616d00004851cba3ae11b1c97fa023c086e0",
              "width": 64
            }
          ],
          "name": "Amit Sharad Trivedi",
          "popularity": 0,
          "type": "artist",
          "uri": "spotify:artist:7otKEEPmJw1z4m8DzxGrQR"
        },
        {
          "external_urls": {
            "spotify": "https://open.spotify.com/artist/0E02VcvA5p1ndkLdqWD5JB"
          },
          "followers": {
            "href": null,
            "total": 13551843
          },
          "genres": [
            "filmi",
            "modern bollywood"
          ],
          "href": "https://api.spotify.com/v1/artists/0E02VcvA5p1ndkLdqWD5JB",
          "id": "0E02VcvA5p1ndkLdqWD5JB",
          "images": [
            {
              "height": 640,
              "url": "https://i.scdn.co/image/ab6761610000e5eb4d9659081d3facaf14e427b1",
              "width": 640
            },
            {
              "height": 320,
              "url": "https://i.scdn.co/image/ab676161000051744d9659081d3facaf14e427b1",
              "width": 320
            },
            {
              "height": 160,
              "url": "https://i.scdn.co/image/ab6761610000f1784d9659081d3facaf14e427b1",
              "width": 160
            }
          ],
          "name": "Ankit Tiwari",
          "popularity": 65,
          "type": "artist",
          "uri": "spotify:artist:0E02VcvA5p1ndkLdqWD5JB"
        }
      ],
      "limit": 20,
      "next": "https://api.spotify.com/v1/search?query=Amit+Trivedi&type=artist&offset=20&limit=20",
      "offset": 0,
      "previous": null,
      "total": 633
    }
  }
  


y = x["artists"]['items']
for i in y:
    print(i['followers']['total'])
# Out:
# 8611348
# 14495
# 638421
# 2889
# 27414316
# 1
# 702769
# 0
# 887977
# 14
# 13551843

# %%
import pandas as pd 
null = None

data_list = []
for i in y:

    data = {
        "artist_name" : i["name"],
        "artist_id" : i["id"],
        "artist_followers" : i["followers"]["total"],
        "artist_generes" : i['genres']
    }

    data_list.append(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 null = None
#       4 data_list = []
# ----> 5 for i in y:
#       7     data = {
#       8         "artist_name" : i["name"],
#       9         "artist_id" : i["id"],
#      10         "artist_followers" : i["followers"]["total"],
#      11         "artist_generes" : i['genres']
#      12     }
#      14     data_list.append(data)
#
# NameError: name 'y' is not defined

# %%
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                                       artist_name               artist_id  \
# 0                                    Amit Trivedi  7HCqGPJcQTyGJ2yqntbuyr
# 1     Amit Trivedi, Shashaa Tirupati, Yazin Nizar  3TttERM9n1ASk6Afa8Vgjt
# 2                            Amitabh Bhattacharya  2fMqTqiTxUDlmcOEPaQSsx
# 3   Shreya Ghoshal, Amit Trivedi, Anurag Kulkarni  3l5NND98Neru33dXEYX7ie
# 4                             Anirudh Ravichander  4zCH9qm4R2DADamUHMCa6O
# 5   Amit Trivedi, Shalmali Kholgade, Kausar Munir  4RAVctZo368nx7X8vGQYts
# 6                            The Amity Affliction  6kNKUYGn6VNGsRoXmyoDPK
# 7          Bhoomi Trivedi, Siddharth Amit Bhavsar  1SSLxaY24HiCbAJxOijTnB
# 8                                     Amit Mishra  2LgKrgRJcbJlt14i1LTzDU
# 9                             Amit Sharad Trivedi  7otKEEPmJw1z4m8DzxGrQR
# 10                                   Ankit Tiwari  0E02VcvA5p1ndkLdqWD5JB
#
#     artist_followers                                     artist_generes
# ...

# %%
z = pd.read_csv("Amit Trivedi data")
z
# Out:
#     Unnamed: 0                                    artist_name  \
# 0            0                                   Amit Trivedi
# 1            1    Amit Trivedi, Shashaa Tirupati, Yazin Nizar
# 2            2                           Amitabh Bhattacharya
# 3            3  Shreya Ghoshal, Amit Trivedi, Anurag Kulkarni
# 4            4                            Anirudh Ravichander
# 5            5  Amit Trivedi, Shalmali Kholgade, Kausar Munir
# 6            6                           The Amity Affliction
# 7            7         Bhoomi Trivedi, Siddharth Amit Bhavsar
# 8            8                                    Amit Mishra
# 9            9                            Amit Sharad Trivedi
# 10          10                                   Ankit Tiwari
# 11          11                                   Amit Trivedi
# 12          12                                    Amit Tandon
# 13          13                                   Amit Trivedi
# ...
